# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots

# %% [markdown]
# # Chapter 2.4, Problem 9

# %% [markdown]
# ### a)
# If we are being generous/inclusive, we can say that of the 8 predictors, 6 are quantitative with only Origin and Cylinders not being (if we do not consider the index/name column as a predictor). However, one could also argue that year are also categorical since there is no use of partial years in the dataset though it is technically interpretable.

# %%
# Get data and drop empty rows
auto = pd.read_csv('Auto.csv', na_values=['?'])
auto = auto.dropna()
auto.set_index('name')
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1
# ...                                 ...   ...     ...
# ford mustang gl                    15.6    82       1
# vw pickup                          24.6    82       2
# dodge rampage                      11.6    82       1
# ford ranger                        18.6    82       1
# chevy s-10                         19.4    82       1
#
# [392 rows x 8 columns]

# %% [markdown]
# ### b)

# %%
# Calculate the range of predictors
min_mpg, max_mpg = np.min(auto['mpg']), np.max(auto['mpg'])
min_displacement,  max_displacement = np.min(auto['displacement']), np.max(auto['displacement'])
min_horsepower,  max_horsepower = np.min(auto['horsepower']), np.max(auto['horsepower'])
min_weight,  max_weight = np.min(auto['weight']), np.max(auto['weight'])
min_acceleration,  max_acceleration = np.min(auto['acceleration']), np.max(auto['acceleration'])

print(f"Min mpg: {min_mpg}")
print(f"Max mpg: {max_mpg}")

print(f"Min displacement: {min_displacement}")
print(f"Max displacement: {max_displacement}")

print(f"Min horsepower: {min_horsepower}")
print(f"Max horsepower: {max_horsepower}")

print(f"Min weight: {min_weight}")
print(f"Max weight: {max_weight}")

print(f"Min acceleration: {min_acceleration}")
print(f"Max acceleration: {max_acceleration}")
# Out:
# Min mpg: 9.0
# Max mpg: 46.6
# Min displacement: 68.0
# Max displacement: 455.0
# Min horsepower: 46.0
# Max horsepower: 230.0
# Min weight: 1613
# Max weight: 5140
# Min acceleration: 8.0
# Max acceleration: 24.8

# %% [markdown]
# ### c)

# %%
# Calculates the average and standard deviation
mean_mpg, std_mpg = np.mean(auto['mpg']), np.std(auto['mpg'])
mean_displacement,  std_displacement = np.mean(auto['displacement']), np.std(auto['displacement'])
mean_horsepower,  std_horsepower = np.mean(auto['horsepower']), np.std(auto['horsepower'])
mean_weight,  std_weight = np.mean(auto['weight']), np.std(auto['weight'])
mean_acceleration,  std_acceleration = np.mean(auto['acceleration']), np.std(auto['acceleration'])

print(f"Mean mpg: {min_mpg}")
print(f"Std mpg: {max_mpg}")

print(f"Mean displacement: {min_displacement}")
print(f"Std displacement: {max_displacement}")

print(f"Mean horsepower: {min_horsepower}")
print(f"Std horsepower: {max_horsepower}")

print(f"Mean weight: {min_weight}")
print(f"Std weight: {max_weight}")

print(f"Mean acceleration: {min_acceleration}")
print(f"Std acceleration: {max_acceleration}")
# Out:
# Mean mpg: 9.0
# Std mpg: 46.6
# Mean displacement: 68.0
# Std displacement: 455.0
# Mean horsepower: 46.0
# Std horsepower: 230.0
# Mean weight: 1613
# Std weight: 5140
# Mean acceleration: 8.0
# Std acceleration: 24.8

# %% [markdown]
# ### d)

# %%
# create data set without entries 10-85 inclusively
ommited = auto.drop(auto.index[10:86])
ommited
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1            ford mustang gl
# 393       2                  vw pickup
# 394       1              dodge rampage
# 395       1                ford ranger
# 396       1                 chevy s-10
#
# [316 rows x 9 columns]

# %%
# Recalculate range, mean, std with ommited data
min_mpg, max_mpg = np.min(ommited['mpg']), np.max(ommited['mpg'])
min_displacement,  max_displacement = np.min(ommited['displacement']), np.max(ommited['displacement'])
min_horsepower,  max_horsepower = np.min(ommited['horsepower']), np.max(ommited['horsepower'])
min_weight,  max_weight = np.min(ommited['weight']), np.max(ommited['weight'])
min_acceleration,  max_acceleration = np.min(ommited['acceleration']), np.max(ommited['acceleration'])

print(f"Min mpg: {min_mpg}")
print(f"Max mpg: {max_mpg}")

print(f"Min displacement: {min_displacement}")
print(f"Max displacement: {max_displacement}")

print(f"Min horsepower: {min_horsepower}")
print(f"Max horsepower: {max_horsepower}")

print(f"Min weight: {min_weight}")
print(f"Max weight: {max_weight}")

print(f"Min acceleration: {min_acceleration}")
print(f"Max acceleration: {max_acceleration}")

mean_mpg, std_mpg = np.mean(ommited['mpg']), np.std(ommited['mpg'])
mean_displacement,  std_displacement = np.mean(ommited['displacement']), np.std(ommited['displacement'])
mean_horsepower,  std_horsepower = np.mean(ommited['horsepower']), np.std(ommited['horsepower'])
mean_weight,  std_weight = np.mean(ommited['weight']), np.std(ommited['weight'])
mean_acceleration,  std_acceleration = np.mean(ommited['acceleration']), np.std(ommited['acceleration'])

print(f"Mean mpg: {min_mpg}")
print(f"Std mpg: {max_mpg}")

print(f"Mean displacement: {min_displacement}")
print(f"Std displacement: {max_displacement}")

print(f"Mean horsepower: {min_horsepower}")
print(f"Std horsepower: {max_horsepower}")

print(f"Mean weight: {min_weight}")
print(f"Std weight: {max_weight}")

print(f"Mean acceleration: {min_acceleration}")
print(f"Std acceleration: {max_acceleration}")
# Out:
# Min mpg: 11.0
# Max mpg: 46.6
# Min displacement: 68.0
# Max displacement: 455.0
# Min horsepower: 46.0
# Max horsepower: 230.0
# Min weight: 1649
# Max weight: 4997
# Min acceleration: 8.5
# Max acceleration: 24.8
# Mean mpg: 11.0
# Std mpg: 46.6
# Mean displacement: 68.0
# Std displacement: 455.0
# Mean horsepower: 46.0
# Std horsepower: 230.0
# Mean weight: 1649
# Std weight: 4997
# Mean acceleration: 8.5
# Std acceleration: 24.8

# %% [markdown]
# ### e) Graphical Findings

# %% [markdown]
# First, there exists a negative correlation between horsepower and mpg which makes sense as more powerful cars are also less fuel efficient (uses more gas).

# %%
# Visualize horsepower against mpg
fig, ax = subplots(figsize=(8, 8))
ax.plot(auto['horsepower'], auto['mpg'], 'o')
ax.set_title('Horsepower vs. MPG')
# Out:
# Text(0.5, 1.0, 'Horsepower vs. MPG')

# %% [markdown]
# Following up with the above observation, we can see that the more cylinders the car has over 4 also decreases fuel efficiency.

# %%
fig, ax = subplots(figsize=(8, 8))
auto.boxplot('mpg', by='cylinders', ax=ax);

# %% [markdown]
# Car fuel efficiency is right skewed with a mean around 23.5 mpg

# %%
fig, ax = subplots(figsize=(8, 8))
auto.hist('mpg', ax=ax);

# %% [markdown]
# Finally, there exists negative correlation between fuel efficiency with both weight and displacement—which makes intuitive sense—and a positive relationship between weight and displacement.

# %%
pd.plotting.scatter_matrix(auto[['mpg','displacement','weight']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>],
#        [<Axes: xlabel='mpg', ylabel='weight'>,
#         <Axes: xlabel='displacement', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>]], dtype=object)

# %% [markdown]
# ### f)
# If we wish to predict gas milage (mpg) using other variables, we can expect that there are some strong predictors in the dataset that could help.
#
# For example, using the above graph, we first saw that the higher the horsepower of a car generally correlates to lower fuel efficiency. Then, we saw a categorical predictor that cars with 4 cylinders are the most fuel efficient in general. Finally, we can also use the car's weight and displacement as variables in our prediction given they seem to have negative correlations with mpg.

# %% [markdown]
# # Chapter 3.7, Problem 8

# %%
import statsmodels.api as sm

# %%
# Single linear regress mgp on predictor horsepower
y = auto['mpg']
X = auto['horsepower']
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Sat, 12 Oct 2024   Prob (F-statistic):           7.03e-81
# Time:                        14:02:16   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.9359      0.717     55.660      0.000      38.525      41.347
# horsepower    -0.1578      0.006    -24.489      0.000      -0.171      -0.145
# ==============================================================================
# Omnibus:                       16.432   Durbin-Watson:                   0.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.305
# Skew:                           0.492   Prob(JB):                     0.000175
# Kurtosis:                       3.299   Cond. No.                         322.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# (i) According to the regression, there indeed does exist a relationship between the predictor (horsepower) and response (mpg).
#
# (ii) In fact, this is a very strong with a t-score of -24.5 which corresponds to a p-value that is below 0.001.
#
# (iii) The relationship between the predictor and response is negative, which means a higher horsepower predicts a lower mpg.

# %% [markdown]
# ### (iv)

# %%
new_prediction = results.get_prediction([1, 85]);
mean_pred = new_prediction.predicted_mean
confidence_interval = new_prediction.conf_int(alpha=0.05)
print("The predicted mpg associated with a horsepower of 98 is", mean_pred[0])
print("The 95% confidence interval associated with this prediction is", confidence_interval[0][0], "to", confidence_interval[0][1])
# Out:
# The predicted mpg associated with a horsepower of 98 is 26.51905868610993
# The 95% confidence interval associated with this prediction is 25.972995818107627 to 27.06512155411223

# %% [markdown]
# ### b)

# %%
def abline(ax, b, m):
    "Add a line with slope m and intercept b to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + b, m * xlim[1] + b]
    ax.plot(xlim, ylim)

# %%
ax = auto.plot.scatter('horsepower', 'mpg')
abline(ax, results.params[0], results.params[1])

# %% [markdown]
# ### c)

# %%
ax = subplots(figsize=(8,8))[1]
ax.scatter(results.fittedvalues , results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--');

# %% [markdown]
# One problem I see with this residual plot is that the predictor's relationship with the response does not seem to be linear. Rather, a quadratic or higher order model may have fit the data better as the residuals grow large and positive at either extremes of horsepower values while the model systematically overestimates mpg around the mean horsepower.

# %% [markdown]
# # Chapter 3.7, Problem 9

# %% [markdown]
# ### a)

# %%
# Explore the data graphically in order to investigate the association between predictors
pd.plotting.scatter_matrix(auto);

# %% [markdown]
# ### b)

# %%
auto.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# year              0.290316  1.000000  0.181528
# origin            0.212746  0.181528  1.000000

# %%
# Include all predictors for mpg besides name
from ISLP.models import (ModelSpec as MS, summarize, poly)
y = auto['mpg']
terms = auto.columns.drop(['name', 'mpg'])
X = MS(terms).fit_transform(auto)
model1 = sm.OLS(y, X)
results1 = model1.fit()
summarize(results1)
# Out:
#                  coef  std err       t  P>|t|
# intercept    -17.2184    4.644  -3.707  0.000
# cylinders     -0.4934    0.323  -1.526  0.128
# displacement   0.0199    0.008   2.647  0.008
# horsepower    -0.0170    0.014  -1.230  0.220
# weight        -0.0065    0.001  -9.929  0.000
# acceleration   0.0806    0.099   0.815  0.415
# year           0.7508    0.051  14.729  0.000
# origin         1.4261    0.278   5.127  0.000

# %%
from statsmodels.stats.anova import anova_lm
anova_lm(results, results1)
# Out:
#    df_resid          ssr  df_diff      ss_diff          F        Pr(>F)
# 0     390.0  9385.915872      0.0          NaN        NaN           NaN
# 1     384.0  4252.212530      6.0  5133.703341  77.267308  5.376746e-63

# %% [markdown]
# ### i)
# The multiple linear regression seems to add some important predictors as the sum of squared residuals went down by more than half when we run anova vs our single linear regression above using only horsepower.
# ### ii)
# Based on the p-values here seems to be some strong predictors for mpg such as displacement, horsepower, weight, year , and origin.
# ### iii)
# The coefficient on year suggest that car produced a year later on average will be more efficient and have a 0.75 higher mpg.

# %% [markdown]
# ## d)

# %%
ax = subplots(figsize=(8,8))[1]
ax.scatter(results1.fittedvalues , results1.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--')

# %% [markdown]
# Despite the additional predictors, it seems that there are still some non-linear trend in the data we can't capture with our linear regression (seemingly a quadratic term might be needed)

# %% [markdown]
# ## e)

# %%
# Adding interaction terms between cylinders and weight as well as horsepower and acceleration
X = MS(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', ('cylinders', 'weight'), ('horsepower', 'acceleration')]).fit_transform(auto)
model2 = sm.OLS(y, X)
results2 = model2.fit()
summarize(results2)
# Out:
#                            coef  std err       t  P>|t|
# intercept               -7.4837    5.516  -1.357  0.176
# cylinders               -4.0179    0.588  -6.835  0.000
# displacement            -0.0049    0.008  -0.646  0.519
# horsepower               0.0807    0.024   3.414  0.001
# weight                  -0.0120    0.001 -10.024  0.000
# acceleration             0.7886    0.151   5.206  0.000
# year                     0.7814    0.045  17.474  0.000
# origin                   0.5834    0.255   2.285  0.023
# cylinders:weight         0.0013    0.000   8.051  0.000
# horsepower:acceleration -0.0093    0.002  -5.533  0.000

# %% [markdown]
# Both the interaction terms between cylindersXweight and horsepowerXacceleration are statistically significant with p-values <0.05

# %% [markdown]
# ## f)

# %%
# Working off observation above, we try adding quadratic term for horsepower
X = MS(['cylinders', 'displacement', 'weight', 'acceleration', 'year', 'origin', poly('horsepower', degree=2)]).fit_transform(auto)
model3 = sm.OLS(y, X)
results3 = model3.fit()
summarize(results3)
# Out:
#                                   coef  std err       t  P>|t|
# intercept                     -19.5846    3.797  -5.158  0.000
# cylinders                       0.3489    0.305   1.145  0.253
# displacement                   -0.0076    0.007  -1.026  0.306
# weight                         -0.0033    0.001  -4.820  0.000
# acceleration                   -0.3306    0.099  -3.333  0.001
# year                            0.7353    0.046  15.989  0.000
# origin                          1.0144    0.255   3.985  0.000
# poly(horsepower, degree=2)[0] -51.2873   10.297  -4.981  0.000
# poly(horsepower, degree=2)[1]  36.0442    3.815   9.449  0.000

# %% [markdown]
# The efectively zero p-value associated with the quadratic term (i.e. the
# last row above) suggests that it leads to an improved model.

# %% [markdown]
# # Chapter 4.8, Problem 14

# %%
# a) Adding mpg01 binary indicator above median mpg as a column
median_mpg = auto['mpg'].median()
mpg01 = [1 if mpg > median_mpg else 0 for mpg in auto['mpg']]
auto['mpg01'] = mpg01
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name  mpg01
# 0         1  chevrolet chevelle malibu      0
# 1         1          buick skylark 320      0
# 2         1         plymouth satellite      0
# 3         1              amc rebel sst      0
# 4         1                ford torino      0
# ..      ...                        ...    ...
# 392       1            ford mustang gl      1
# 393       2                  vw pickup      1
# 394       1              dodge rampage      1
# 395       1                ford ranger      1
# 396       1                 chevy s-10      1
#
# [392 rows x 10 columns]

# %% [markdown]
# ### b)

# %%
# Explore the data graphically in order to investigate the association between mpg01 and the other features
pd.plotting.scatter_matrix(auto)
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>,
#         <Axes: xlabel='mpg01', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='horsepower', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>,
#         <Axes: xlabel='mpg01', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='horsepower', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
#         <Axes: xlabel='acceleration', ylabel='displacement'>,
#         <Axes: xlabel='year', ylabel='displacement'>,
#         <Axes: xlabel='origin', ylabel='displacement'>,
#         <Axes: xlabel='mpg01', ylabel='displacement'>],
#        [<Axes: xlabel='mpg', ylabel='horsepower'>,
#         <Axes: xlabel='cylinders', ylabel='horsepower'>,
#         <Axes: xlabel='displacement', ylabel='horsepower'>,
#         <Axes: xlabel='horsepower', ylabel='horsepower'>,
#         <Axes: xlabel='weight', ylabel='horsepower'>,
#         <Axes: xlabel='acceleration', ylabel='horsepower'>,
#         <Axes: xlabel='year', ylabel='horsepower'>,
#         <Axes: xlabel='origin', ylabel='horsepower'>,
#         <Axes: xlabel='mpg01', ylabel='horsepower'>],
#        [<Axes: xlabel='mpg', ylabel='weight'>,
#         <Axes: xlabel='cylinders', ylabel='weight'>,
#         <Axes: xlabel='displacement', ylabel='weight'>,
#         <Axes: xlabel='horsepower', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>,
#         <Axes: xlabel='acceleration', ylabel='weight'>,
#         <Axes: xlabel='year', ylabel='weight'>,
#         <Axes: xlabel='origin', ylabel='weight'>,
#         <Axes: xlabel='mpg01', ylabel='weight'>],
#        [<Axes: xlabel='mpg', ylabel='acceleration'>,
#         <Axes: xlabel='cylinders', ylabel='acceleration'>,
#         <Axes: xlabel='displacement', ylabel='acceleration'>,
#         <Axes: xlabel='horsepower', ylabel='acceleration'>,
#         <Axes: xlabel='weight', ylabel='acceleration'>,
#         <Axes: xlabel='acceleration', ylabel='acceleration'>,
#         <Axes: xlabel='year', ylabel='acceleration'>,
#         <Axes: xlabel='origin', ylabel='acceleration'>,
#         <Axes: xlabel='mpg01', ylabel='acceleration'>],
#        [<Axes: xlabel='mpg', ylabel='year'>,
#         <Axes: xlabel='cylinders', ylabel='year'>,
#         <Axes: xlabel='displacement', ylabel='year'>,
#         <Axes: xlabel='horsepower', ylabel='year'>,
#         <Axes: xlabel='weight', ylabel='year'>,
#         <Axes: xlabel='acceleration', ylabel='year'>,
#         <Axes: xlabel='year', ylabel='year'>,
#         <Axes: xlabel='origin', ylabel='year'>,
#         <Axes: xlabel='mpg01', ylabel='year'>],
#        [<Axes: xlabel='mpg', ylabel='origin'>,
#         <Axes: xlabel='cylinders', ylabel='origin'>,
#         <Axes: xlabel='displacement', ylabel='origin'>,
#         <Axes: xlabel='horsepower', ylabel='origin'>,
#         <Axes: xlabel='weight', ylabel='origin'>,
#         <Axes: xlabel='acceleration', ylabel='origin'>,
#         <Axes: xlabel='year', ylabel='origin'>,
#         <Axes: xlabel='origin', ylabel='origin'>,
#         <Axes: xlabel='mpg01', ylabel='origin'>],
#        [<Axes: xlabel='mpg', ylabel='mpg01'>,
#         <Axes: xlabel='cylinders', ylabel='mpg01'>,
#         <Axes: xlabel='displacement', ylabel='mpg01'>,
#         <Axes: xlabel='horsepower', ylabel='mpg01'>,
#         <Axes: xlabel='weight', ylabel='mpg01'>,
#         <Axes: xlabel='acceleration', ylabel='mpg01'>,
#         <Axes: xlabel='year', ylabel='mpg01'>,
#         <Axes: xlabel='origin', ylabel='mpg01'>,
#         <Axes: xlabel='mpg01', ylabel='mpg01'>]], dtype=object)

# %% [markdown]
# Looking at the last column above, there seems to be  correlations between mpg01 and horsepower and weight as well as acceleration

# %%
from sklearn.discriminant_analysis import \
(LinearDiscriminantAnalysis as LDA,
QuadraticDiscriminantAnalysis as QDA)
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### c)

# %%
# Create Train and Test sets
train = (auto.year < 80)
test = (auto.year >= 80)
auto_train = auto.loc[train]
auto_train = auto_train[['horsepower','weight', 'acceleration']]
auto_test = auto.loc[test]
auto_test = auto_test[['horsepower','weight', 'acceleration']]
print("Train", auto_train.shape, "Test",auto_test.shape)
# Out:
# Train (307, 3) Test (85, 3)

# %% [markdown]
# ### d) LDA

# %%
lda = LDA(store_covariance=True)
D = auto.mpg01
L_train, L_test = D.loc[train], D.loc[test]

# %%
lda.fit(auto_train, L_train)
lda_pred = lda.predict(auto_test)

# %%
lda.priors_
# Out:
# array([0.62214984, 0.37785016])

# %%
from ISLP import confusion_table
confusion_table(lda_pred, L_test)
# Out:
# Truth      0   1
# Predicted
# 0          4  14
# 1          1  66

# %% [markdown]
# LDA has a test error of 15/85 or ~18%

# %% [markdown]
# ### e) QDA

# %%
lda = QDA(store_covariance=True)
D = auto.mpg01
L_train, L_test = D.loc[train], D.loc[test]
lda.fit(auto_train, L_train)
lda_pred = lda.predict(auto_test)

# %%
# Test predictions
confusion_table(lda_pred, L_test)
# Out:
# Truth      0   1
# Predicted
# 0          5  11
# 1          0  69

# %% [markdown]
# QDA has a test error of 11/85 or ~13% which is better than LDA
